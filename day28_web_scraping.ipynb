# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
search_ele = "oppo mobiles"
url = "https://www.flipkart.com/search?q="+search_ele.replace(" ","")
url
# Out:
# 'https://www.flipkart.com/search?q=oppomobiles'

# %%
respone = requests.get(url)

# %%
#Define custom headers
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'}

response = requests.get(url, headers = headers)
response
# Out:
# <Response [200]>

# %%
  web_page = bs(response.text, 'html.parser')

# %%
products = web_page.find_all('div', {'class':'lvJbLV col-12-12'})
print(len(products))
# Out:
# 30

# %%
product = products[3]

# %%
product.div.div.div.a['href']
# Out:
# '/oppo-k13-5g-7000mah-80w-supervooc-charger-in-the-box-prism-black-128-gb/p/itm6f2ebf6d205cf?pid=MOBHB392JAQKDGBF&lid=LSTMOBHB392JAQKDGBF1CMXCI&marketplace=FLIPKART&q=oppomobiles&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=48c4b636-c94a-4176-bd06-876c8bb2dae5.MOBHB392JAQKDGBF.SEARCH&ppt=None&ppn=None&ssid=m2sfmhyhgg0000001775279154554&qH=b8baa03fb15e9682&ov_redirect=true'

# %%
"https://www.flipkart.com"+product.div.div.div.a['href']
# Out:
# 'https://www.flipkart.com/oppo-k13-5g-7000mah-80w-supervooc-charger-in-the-box-prism-black-128-gb/p/itm6f2ebf6d205cf?pid=MOBHB392JAQKDGBF&lid=LSTMOBHB392JAQKDGBF1CMXCI&marketplace=FLIPKART&q=oppomobiles&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=48c4b636-c94a-4176-bd06-876c8bb2dae5.MOBHB392JAQKDGBF.SEARCH&ppt=None&ppn=None&ssid=m2sfmhyhgg0000001775279154554&qH=b8baa03fb15e9682&ov_redirect=true'

# %%
product_links=[]
for product in products:
    try:
        product_link = "https://www.flipkart.com"+product.div.div.div.a['href']
        product_links.append(product_link)
    except:
        pass
print(len(product_links))
# Out:
# 24

# %%
product_link = product_links[0]
product_link
# Out:
# 'https://www.flipkart.com/oppo-k14x-5g-icy-blue-64-gb/p/itm188c7a4b69292?pid=MOBHKZF3YEJNPZHZ&lid=LSTMOBHKZF3YEJNPZHZKAKWY1&marketplace=FLIPKART&q=oppomobiles&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=48c4b636-c94a-4176-bd06-876c8bb2dae5.MOBHKZF3YEJNPZHZ.SEARCH&ppt=None&ppn=None&ssid=m2sfmhyhgg0000001775279154554&qH=b8baa03fb15e9682&ov_redirect=true'
